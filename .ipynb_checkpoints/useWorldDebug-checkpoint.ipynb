# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pickle
from useWorld import *

# %%
with open("DemoWorld/world.p", 'rb') as fl:
    world = pickle.load(fl)
with open("DemoWorld/demographics.p", 'rb') as fl:
    demos = pickle.load(fl)

# %%
f,a = ShowSquare((1.7,-1.6),(2.6,-0.3),world)

# %%
Hompea = Region((1.7,-1.6),(2.6,-0.3),world,demos)

# %%
Hompea.Cities
# Out:
#                                        Location            Population Name
# C0    (1.9597194388777555, -1.5817635270541084)  [0.9993877264394878]
# C1    (1.9885771543086173, -1.5244488977955912)   [3.137884253465791]
# C2     (1.954308617234469, -1.4619238476953909)   [5.451134799507257]
# C3    (2.1400801603206414, -1.4072144288577155)   [369.8447477669101]
# C4    (2.0733466933867737, -1.3472945891783568)  [339.35321671593414]
# ..                                          ...                   ...  ...
# C57  (2.4629258517034067, -0.39378757515030083)  [192.11373336183303]
# C58                   (2.6, -0.391182364729459)   [97.94022675879174]
# C59   (2.358316633266533, -0.37815631262525073)  [218.82412575061662]
# C60    (2.5098196392785574, -0.326052104208417)   [136.8237675229728]
# C61   (2.3925851703406815, -0.3052104208416835)   [201.0555191808576]
#
# [62 rows x 3 columns]

# %%
fig = Hompea.ShowMap(top = 0.8,bottom = 0.2,left = 0.6,right = 0.9, labelCities = True, cityLabel="num")

# %%
Hompea.NameCities()
Hompea.Cities.loc['C43',"Name"] = "Prinshey"
Hompea.Cities.loc['C49',"Name"] = "Domshey"

# %%
Hompea.ShowMap(top = 0.8,bottom = 0.2,left = 0.6,right = 0.9, labelCities = True, cityLabel="Name")

# %%
Hompea.DemographicStats

# %%
Hompea.DemographicStats[[1,218]].plot.bar()

# %%
CityDf = pd.DataFrame(index = [ci[0] for ci in Hompea.Cities], columns = )
